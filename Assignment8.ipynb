# %% [markdown]
# # Programming Assignment 8

# %% [markdown]
# ## Objectives
#
# **The purpose of this assignment is to:**
#
# - Practice opening a text file, read it in, and manipulate the contents
# - Use exception handling to avoid FileNotFoundError exceptions
# - To practice using a dictionary

# %% [markdown]
# ### Using this Notebook

# %% [markdown]
# Notice that some of the cells are not able to be edited – they are just meant to be run to test your code, and perform the auto grading.  You should begin at the top and execute each code cell, adding your code when you see # YOUR CODE HERE.  If you have written the functions correctly, you should see no errors.
#
# When you execute the TEST CASES cell, what you want to see is no output.  You may want to intentionally make the function give a wrong result, so that you can see what the error message looks like – and then fix your function.  Once you execute the TEST CASES cell, and get no output, then your function is most likely correct!

# %% [markdown]
# ## Assignment Instructions

# %% [markdown]
# Write a program that will process a file, and count the number of occurrences of each word, storing the results in a dictionary.  As a sample file, we will use the plain text version of Shakespeare's Macbeth, available on the Project Gutenberg website, here: https://www.gutenberg.org/cache/epub/2264/pg2264.txt This file is provided in the Jupyter Lab environment as `Macbeth.txt`.
#
# ### Function 1: process_file(filename)
# Write a function that will open a text file, read each line, and add all words on that line to a dictionary, and finally return the dictionary.
#
# 1) Use the try/catch and with open(filename...) method to open the file, as demonstrated in [Live Coding lecture from this week](https://www.coursera.org/learn/ball-state-univeristy-introduction-to-programming/item/jPzz4).  To start with, use a for loop to print out each line of the file, so that you know it is working..
#     * Test your code to make sure your exception handling is working -- if you use the wrong filename, do you get a printed error message, not a crash?
#     * If you type in the correct filename, is the file opened correctly?

# %% [markdown]
# 2) Now, modify the for loop from step 1.  Our overall goal is to take each line....split it into a list of words...then for each word...count it using a dictionary.  This can be accomplished by the following pseudocode.  Translate this to real python.  (Hint: Look at the Live Coding: Dictionary Example from Module 7.)

# %% [raw]
#         # Pseudocode:
#         for each line in the data file
#            split that line up into individual words in a list (hint: use
#            .split())
#            then, for each word in that list
#               if that word is a key in the dictionary
#                   add one to the value stored for that key
#               otherwise (this is a new word)
#                   add this key to the dictionary, with a starting value of 1 </code>

# %% [markdown]
# - **Hint:** you may want to put this pseudocode in your function, and gradually add each line. As you enter the code, be sure to test it frequently (and use the debugger to visualize what is happening!)

# %% [markdown]
# 3. Return the dictionary.

# %% [markdown]
# ### Step 1: Implement the process_file function

# %%
def process_file(filename):
    my_dict = {}
    my_list = []
    try: 
       with open(filename, 'r') as file:
        for each_line in file:
            my_list += each_line.split()
        for each in my_list:
            if each in my_dict:
                my_dict[each] += 1
            else:
                my_dict[each] = 1
        return my_dict
    except FileNotFoundError:
        return f"There is no file named {filename} in this directory."

process_file('Macbeth.txt')
# Out:
# {'The': 117,
#  'Tragedie': 1,
#  'of': 314,
#  'Macbeth': 26,
#  'Actus': 5,
#  'Primus.': 1,
#  'Scoena': 1,
#  'Prima.': 5,
#  'Thunder': 2,
#  'and': 375,
#  'Lightning.': 1,
#  'Enter': 73,
#  'three': 13,
#  'Witches.': 4,
#  '1.': 21,
#  'When': 21,
#  'shall': 47,
#  'we': 56,
#  'meet': 5,
#  'againe?': 2,
#  'In': 28,
#  'Thunder,': 1,
#  'Lightning,': 1,
#  'or': 25,
#  'in': 167,
#  'Raine?': 1,
#  '2.': 12,
#  'the': 528,
#  "Hurley-burley's": 1,
#  'done,': 7,
#  "Battaile's": 1,
#  'lost,': 3,
#  'wonne': 1,
#  '3.': 14,
#  'That': 80,
#  'will': 59,
#  'be': 119,
#  'ere': 13,
#  'set': 7,
#  'Sunne': 3,
#  'Where': 20,
#  'place?': 2,
#  'Vpon': 11,
#  'Heath': 2,
#  'There': 12,
#  'to': 310,
#  'with': 133,
#  'I': 314,
#  'come,': 8,
#  'Gray-Malkin': 1,
#  'All.': 13,
#  'Padock': 1,
#  'calls': 2,
#  'anon:': 1,
#  'faire': 3,
#  'is': 156,
#  'foule,': 2,
#  'foule': 2,
#  'faire,': 1,
#  'Houer': 1,
#  'through': 6,
#  'fogge': 1,
#  'filthie': 2,
#  'ayre.': 1,
#  'Exeunt.': 29,
#  'Scena': 22,
#  'Secunda.': 5,
#  'Alarum': 5,
#  'within.': 7,
#  'King,': 19,
#  'Malcome,': 1,
#  'Donalbaine,': 3,
#  'Lenox,': 8,
#  'attendants,': 1,
#  'meeting': 2,
#  'a': 212,
#  'bleeding': 1,
#  'Captaine.': 1,
#  'King.': 18,
#  'What': 57,
#  'bloody': 11,
#  'man': 16,
#  'that?': 2,
#  'he': 73,
#  'can': 20,
#  'report,': 3,
#  'As': 33,
#  'seemeth': 1,
#  'by': 33,
#  'his': 126,
#  'plight,': 1,
#  'Reuolt': 1,
#  'newest': 3,
#  'state': 3,
#  'Mal.': 25,
#  'This': 24,
#  'Serieant,': 1,
#  'Who': 21,
#  'like': 31,
#  'good': 33,
#  'hardie': 1,
#  'Souldier': 2,
#  'fought': 1,
#  "'Gainst": 2,
#  'my': 168,
#  'Captiuitie:': 1,
#  'Haile': 4,
#  'braue': 2,
#  'friend;': 1,
#  'Say': 3,
#  'knowledge': 1,
#  'Broyle,': 1,
#  'thou': 61,
#  'didst': 2,
#  'leaue': 10,
#  'it': 111,
#  'Cap.': 3,
#  'Doubtfull': 1,
#  'stood,': 2,
#  'two': 8,
#  'spent': 1,
#  'Swimmers,': 1,
#  'that': 140,
#  'doe': 26,
#  'cling': 2,
#  'together,': 2,
#  'And': 169,
#  'choake': 1,
#  'their': 57,
#  'Art:': 1,
#  'mercilesse': 1,
#  'Macdonwald': 1,
#  '(Worthie': 1,
#  'Rebell,': 1,
#  'for': 77,
#  'multiplying': 1,
#  'Villanies': 1,
#  'Nature': 12,
#  'Doe': 4,
#  'swarme': 1,
#  'vpon': 47,
#  'him)': 2,
#  'from': 47,
#  'Westerne': 1,
#  'Isles': 1,
#  'Of': 22,
#  'Kernes': 2,
#  'Gallowgrosses': 1,
#  "supply'd,": 1,
#  'Fortune': 1,
#  'on': 47,
#  'damned': 2,
#  'Quarry': 2,
#  'smiling,': 1,
#  "Shew'd": 1,
#  'Rebells': 1,
#  'Whore:': 1,
#  'but': 60,
#  "all's": 3,
#  'too': 17,
#  'weake:': 1,
#  'For': 30,
#  '(well': 1,
#  'hee': 6,
#  'deserues': 2,
#  'Name)': 1,
#  'Disdayning': 1,
#  'Fortune,': 4,
#  'brandisht': 1,
#  'Steele,': 2,
#  'Which': 35,
#  "smoak'd": 1,
#  'execution': 3,
#  '(Like': 1,
#  'Valours': 1,
#  'Minion)': 1,
#  "caru'd": 1,
#  'out': 15,
#  'passage,': 1,
#  'Till': 11,
#  "fac'd": 1,
#  'Slaue:': 1,
#  "neu'r": 1,
#  'shooke': 1,
#  'hands,': 4,
#  'nor': 20,
#  'bad': 4,
#  'farwell': 1,
#  'him,': 18,
#  "vnseam'd": 1,
#  'him': 56,
#  'Naue': 1,
#  "toth'": 4,
#  'Chops,': 1,
#  "fix'd": 1,
#  'Head': 2,
#  'our': 103,
#  'Battlements': 1,
#  'O': 13,
#  'valiant': 3,
#  'Cousin,': 2,
#  'worthy': 13,
#  'Gentleman': 1,
#  'whence': 4,
#  "'gins": 1,
#  'reflection,': 1,
#  'Shipwracking': 1,
#  'Stormes,': 1,
#  'direfull': 1,
#  'Thunders:': 1,
#  'So': 26,
#  'Spring,': 2,
#  'comfort': 4,
#  "seem'd": 2,
#  'Discomfort': 1,
#  'swells:': 1,
#  'Marke': 1,
#  'King': 14,
#  'Scotland,': 4,
#  'marke,': 1,
#  'No': 16,
#  'sooner': 2,
#  'Iustice': 2,
#  'had,': 2,
#  'Valour': 1,
#  "arm'd,": 1,
#  "Compell'd": 1,
#  'these': 20,
#  'skipping': 1,
#  'trust': 2,
#  'heeles,': 2,
#  'But': 60,
#  'Norweyan': 3,
#  'Lord,': 17,
#  'surueying': 1,
#  'vantage,': 1,
#  'With': 19,
#  'furbusht': 1,
#  'Armes,': 1,
#  'new': 9,
#  'supplyes': 1,
#  'men,': 7,
#  'Began': 1,
#  'fresh': 1,
#  'assault': 1,
#  "Dismay'd": 1,
#  'not': 135,
#  'this': 71,
#  'Captaines,': 1,
#  'Banquoh?': 1,
#  'Yes,': 2,
#  'as': 52,
#  'Sparrowes,': 1,
#  'Eagles;': 1,
#  'Or': 12,
#  'Hare,': 1,
#  'Lyon:': 1,
#  'If': 28,
#  'say': 19,
#  'sooth,': 2,
#  'must': 33,
#  'report': 5,
#  'they': 56,
#  'were': 32,
#  'Cannons': 1,
#  "ouer-charg'd": 1,
#  'double': 4,
#  'Cracks,': 1,
#  'doubly': 1,
#  'redoubled': 1,
#  'stroakes': 2,
#  'Foe:': 1,
#  'Except': 1,
#  'meant': 1,
#  'bathe': 1,
#  'reeking': 1,
#  'Wounds,': 1,
#  'memorize': 1,
#  'another': 4,
#  'Golgotha,': 1,
#  'cannot': 18,
#  'tell:': 1,
#  'am': 28,
#  'faint,': 1,
#  'My': 33,
#  'Gashes': 1,
#  'cry': 2,
#  'helpe': 3,
#  'well': 9,
#  'thy': 46,
#  'words': 4,
#  'become': 4,
#  'thee,': 8,
#  'wounds,': 1,
#  'They': 12,
#  'smack': 1,
#  'Honor': 6,
#  'both:': 2,
#  'Goe': 5,
#  'get': 5,
#  'Surgeons.': 1,
#  'Rosse': 3,
#  'Angus.': 3,
#  'comes': 9,
#  'here?': 3,
#  'Thane': 19,
#  'Lenox.': 20,
#  'haste': 1,
#  'lookes': 1,
#  'eyes?': 1,
#  'should': 39,
#  'looke,': 2,
#  'seemes': 4,
#  'speake': 17,
#  'things': 17,
#  'strange': 10,
#  'Rosse.': 40,
#  'God': 12,
#  'saue': 1,
#  'Whence': 2,
#  "cam'st": 1,
#  'thou,': 1,
#  'Thane?': 2,
#  'From': 9,
#  'Fiffe,': 1,
#  'great': 24,
#  'Banners': 2,
#  'flowt': 1,
#  'Skie,': 1,
#  'fanne': 1,
#  'people': 2,
#  'cold.': 2,
#  'Norway': 1,
#  'himselfe,': 1,
#  'terrible': 4,
#  'numbers,': 1,
#  'Assisted': 1,
#  'most': 20,
#  'disloyall': 1,
#  'Traytor,': 1,
#  'Cawdor,': 5,
#  'began': 2,
#  'dismall': 2,
#  'Conflict,': 1,
#  "Bellona's": 1,
#  'Bridegroome,': 1,
#  'lapt': 1,
#  'proofe,': 1,
#  'Confronted': 1,
#  'selfe-comparisons,': 1,
#  'Point': 1,
#  'against': 9,
#  'Point,': 1,
#  'rebellious': 1,
#  'Arme': 1,
#  "'gainst": 2,
#  'Arme,': 3,
#  'Curbing': 1,
#  'lauish': 1,
#  'spirit:': 1,
#  'conclude,': 1,
#  'Victorie': 1,
#  'fell': 4,
#  'vs': 42,
#  'Great': 6,
#  'happinesse': 1,
#  'now': 26,
#  'Sweno,': 1,
#  'Norwayes': 1,
#  'Craues': 1,
#  'composition:': 1,
#  'Nor': 4,
#  'would': 35,
#  'deigne': 1,
#  'buriall': 1,
#  'disbursed,': 1,
#  'at': 42,
#  'Saint': 1,
#  'Colmes': 1,
#  'ynch,': 1,
#  'Ten': 1,
#  'thousand': 4,
#  'Dollars,': 1,
#  'generall': 3,
#  'vse': 4,
#  'more': 31,
#  'Cawdor': 8,
#  'deceiue': 1,
#  'Our': 20,
#  'Bosome': 2,
#  'interest:': 1,
#  'pronounce': 3,
#  'present': 3,
#  'death,': 4,
#  'former': 4,
#  'Title': 4,
#  'greet': 2,
#  'Ile': 35,
#  'see': 23,
#  'done': 19,
#  'hath': 37,
#  'Noble': 12,
#  'wonne.': 1,
#  'Tertia.': 5,
#  'Thunder.': 6,
#  'hast': 6,
#  'beene,': 2,
#  'Sister?': 1,
#  'Killing': 1,
#  'Swine': 1,
#  'Sister,': 1,
#  'where': 14,
#  'thou?': 1,
#  'A': 26,
#  'Saylors': 1,
#  'Wife': 4,
#  'had': 27,
#  'Chestnuts': 1,
#  'her': 33,
#  'Lappe,': 1,
#  'mouncht,': 2,
#  '&': 17,
#  'mouncht:': 1,
#  'Giue': 13,
#  'me,': 21,
#  'quoth': 1,
#  'I.': 1,
#  'Aroynt': 1,
#  'Witch,': 1,
#  'rumpe-fed': 1,
#  'Ronyon': 1,
#  'cryes.': 1,
#  'Her': 3,
#  "Husband's": 1,
#  'Aleppo': 1,
#  'gone,': 3,
#  'Master': 4,
#  "o'th'": 13,
#  'Tiger:': 1,
#  'Syue': 1,
#  'thither': 3,
#  'sayle,': 1,
#  'Rat': 1,
#  'without': 10,
#  'tayle,': 1,
#  'doe,': 7,
#  'giue': 11,
#  'thee': 43,
#  'Winde': 1,
#  "Th'art": 1,
#  'kinde': 2,
#  'selfe': 14,
#  'haue': 114,
#  'all': 53,
#  'other,': 5,
#  'very': 10,
#  'Ports': 1,
#  'blow,': 1,
#  'All': 20,
#  'Quarters': 1,
#  'know,': 4,
#  "I'th'": 1,
#  'Ship-mans': 1,
#  'Card.': 1,
#  'dreyne': 1,
#  'drie': 1,
#  'Hay:': 1,
#  'Sleepe': 3,
#  'neyther': 2,
#  'Night': 13,
#  'Day': 3,
#  'Hang': 4,
#  'Pent-house': 1,
#  'Lid:': 1,
#  'He': 34,
#  'liue': 5,
#  'forbid:': 1,
#  'Wearie': 1,
#  "Seu'nights,": 1,
#  'nine': 2,
#  'times': 3,
#  'nine,': 1,
#  'Shall': 20,
#  'dwindle,': 1,
#  'peake,': 1,
#  'pine:': 1,
#  'Though': 11,
#  'Barke': 1,
#  'Yet': 7,
#  'Tempest-tost.': 1,
#  'Looke': 8,
#  'what': 43,
#  'Shew': 5,
#  'shew': 9,
#  'me': 72,
#  'Here': 4,
#  'Pilots': 1,
#  'Thumbe,': 1,
#  'Wrackt,': 1,
#  'homeward': 1,
#  'did': 32,
#  'come.': 2,
#  'Drum': 4,
#  'Drumme,': 1,
#  'Drumme:': 1,
#  'doth': 6,
#  'come': 20,
#  'weyward': 3,
#  'Sisters,': 3,
#  'hand': 4,
#  'hand,': 4,
#  'Posters': 1,
#  'Sea': 3,
#  'Land,': 2,
#  'Thus': 4,
#  'goe,': 2,
#  'about,': 2,
#  'Thrice': 2,
#  'thine,': 3,
#  'thrice': 2,
#  'mine,': 3,
#  'againe,': 3,
#  'make': 33,
#  'vp': 20,
#  'nine.': 1,
#  'Peace,': 1,
#  "Charme's": 1,
#  'wound': 1,
#  'vp.': 1,
#  'Banquo.': 6,
#  'Macb.': 137,
#  'day': 8,
#  'seene': 6,
#  'How': 20,
#  'farre': 3,
#  "is't": 5,
#  "call'd": 4,
#  'Soris?': 1,
#  'are': 55,
#  'these,': 1,
#  "wither'd,": 1,
#  'so': 52,
#  'wilde': 3,
#  'attyre,': 1,
#  'looke': 13,
#  "th'": 21,
#  'Inhabitants': 1,
#  'Earth,': 1,
#  'yet': 45,
#  "on't?": 1,
#  'Liue': 1,
#  'you,': 14,
#  'you': 144,
#  'aught': 1,
#  'may': 25,
#  'question?': 1,
#  'seeme': 7,
#  'vnderstand': 1,
#  'By': 13,
#  'each': 9,
#  'once': 8,
#  'choppie': 1,
#  'finger': 1,
#  'laying': 1,
#  'skinnie': 1,
#  'Lips:': 1,
#  'Women,': 1,
#  'your': 110,
#  'Beards': 1,
#  'forbid': 1,
#  'interprete': 1,
#  'Mac.': 10,
#  'Speake': 3,
#  'if': 14,
#  'can:': 1,
#  'you?': 5,
#  'haile': 9,
#  'Macbeth,': 24,
#  'Glamis': 2,
#  'shalt': 6,
#  'hereafter': 1,
#  'Banq.': 24,
#  'Good': 9,
#  'Sir,': 16,
#  'why': 8,
#  'start,': 2,
#  'feare': 13,
#  'Things': 4,
#  'sound': 4,
#  'faire?': 1,
#  "i'th'": 14,
#  'name': 8,
#  'truth': 5,
#  'Are': 10,
#  'ye': 3,
#  'fantasticall,': 2,
#  'indeed': 3,
#  'outwardly': 1,
#  'shew?': 1,
#  'Partner': 2,
#  'You': 22,
#  'Grace,': 3,
#  'prediction': 1,
#  'hauing,': 1,
#  'Royall': 9,
#  'hope,': 1,
#  'wrapt': 1,
#  'withall:': 1,
#  'not.': 4,
#  'into': 9,
#  'Seedes': 2,
#  'Time,': 4,
#  'say,': 11,
#  'which': 43,
#  'Graine': 1,
#  'grow,': 2,
#  'not,': 11,
#  'then': 31,
#  'who': 19,
#  'begge,': 1,
#  'Your': 16,
#  'fauors,': 1,
#  'hate': 2,
#  'Hayle': 3,
#  'Lesser': 1,
#  'than': 1,
#  'greater': 2,
#  'Not': 10,
#  'happy,': 1,
#  'much': 11,
#  'happyer': 1,
#  'Thou': 24,
#  'Kings,': 4,
#  'though': 6,
#  'none:': 2,
#  'Banquo': 13,
#  'Banquo,': 13,
#  'Stay': 1,
#  'imperfect': 1,
#  'Speakers,': 1,
#  'tell': 6,
#  'more:': 6,
#  'Sinells': 1,
#  'know': 25,
#  'Glamis,': 2,
#  'how,': 1,
#  'Cawdor?': 3,
#  'liues': 6,
#  'prosperous': 1,
#  'Gentleman:': 1,
#  'Stands': 3,
#  'within': 4,
#  'prospect': 1,
#  'beleefe,': 1,
#  'Cawdor.': 3,
#  'owe': 1,
#  'Intelligence,': 1,
#  'blasted': 1,
#  'stop': 1,
#  'way': 11,
#  'such': 20,
#  'Prophetique': 1,
#  'greeting?': 1,
#  'Speake,': 1,
#  'charge': 2,
#  'you.': 8,
#  'Witches': 3,
#  'vanish.': 2,
#  'Earth': 4,
#  'bubbles,': 1,
#  'Water': 3,
#  "ha's,": 1,
#  'them:': 6,
#  'whither': 1,
#  "vanish'd?": 1,
#  'Into': 3,
#  'Ayre:': 3,
#  'corporall,': 1,
#  'Melted,': 1,
#  'breath': 6,
#  'Winde.': 1,
#  'Would': 10,
#  "stay'd": 1,
#  'Were': 6,
#  'here,': 3,
#  'about?': 1,
#  'eaten': 2,
#  'insane': 1,
#  'Root,': 1,
#  'takes': 4,
#  'Reason': 2,
#  'Prisoner?': 1,
#  'Children': 3,
#  'Kings': 2,
#  'too:': 4,
#  'went': 4,
#  'so?': 4,
#  "Toth'": 1,
#  'selfe-same': 2,
#  'tune': 1,
#  'words:': 2,
#  "who's": 2,
#  'happily': 1,
#  "receiu'd,": 2,
#  'newes': 1,
#  'successe:': 2,
#  'when': 18,
#  'reades': 1,
#  'Thy': 10,
#  'personall': 1,
#  'Venture': 1,
#  'Rebels': 1,
#  'sight,': 4,
#  'His': 17,
#  'Wonders': 1,
#  'Prayses': 1,
#  'contend,': 1,
#  'his:': 1,
#  "silenc'd": 1,
#  'that,': 2,
#  'viewing': 1,
#  "o're": 3,
#  'rest': 5,
#  'day,': 3,
#  'findes': 2,
#  'stout': 1,
#  'Rankes,': 1,
#  'Nothing': 4,
#  'afeard': 1,
#  'Strange': 3,
#  'Images': 1,
#  'thick': 3,
#  'Tale': 2,
#  'Can': 4,
#  'post': 1,
#  'post,': 1,
#  'euery': 14,
#  'one': 23,
#  'beare': 8,
#  'prayses': 1,
#  'Kingdomes': 2,
#  'defence,': 2,
#  "powr'd": 1,
#  'them': 26,
#  'downe': 6,
#  'before': 12,
#  'Ang.': 4,
#  'Wee': 1,
#  'sent,': 1,
#  'To': 73,
#  'thanks,': 2,
#  'Onely': 5,
#  'harrold': 1,
#  'pay': 3,
#  'an': 26,
#  'earnest': 2,
#  'Honor,': 3,
#  'call': 7,
#  'Cawdor:': 2,
#  'addition,': 2,
#  'Thane,': 4,
#  'thine': 6,
#  'What,': 4,
#  'Deuill': 2,
#  'true?': 1,
#  'liues:': 2,
#  'Why': 23,
#  'dresse': 1,
#  'borrowed': 1,
#  'Robes?': 1,
#  'was': 31,
#  'yet,': 3,
#  'vnder': 5,
#  'heauie': 4,
#  'Iudgement': 1,
#  'beares': 2,
#  'Life,': 5,
#  'loose.': 1,
#  'Whether': 4,
#  "combin'd": 1,
#  'those': 18,
#  'Norway,': 1,
#  'lyne': 1,
#  'Rebell': 1,
#  'hidden': 1,
#  'helpe,': 1,
#  'vantage;': 1,
#  'both': 11,
#  "labour'd": 1,
#  'Countreyes': 1,
#  'wracke,': 2,
#  'not:': 3,
#  'Treasons': 1,
#  'Capitall,': 1,
#  "confess'd,": 1,
#  "prou'd,": 1,
#  'Haue': 5,
#  'ouerthrowne': 1,
#  'Glamys,': 3,
#  'greatest': 2,
#  'behinde.': 1,
#  'Thankes': 4,
#  'paines.': 1,
#  'hope': 5,
#  'gaue': 2,
#  "Promis'd": 1,
#  'no': 47,
#  'lesse': 8,
#  'trusted': 2,
#  'home,': 1,
#  'Might': 3,
#  'enkindle': 1,
#  'vnto': 1,
#  'Crowne,': 2,
#  'Besides': 1,
#  "'tis": 21,
#  'strange:': 2,
#  'oftentimes,': 1,
#  'winne': 1,
#  'harme,': 1,
#  'Instruments': 1,
#  'Darknesse': 2,
#  'Truths,': 1,
#  'Winne': 1,
#  'honest': 4,
#  'Trifles,': 1,
#  "betray's": 1,
#  'deepest': 1,
#  'consequence.': 1,
#  'Cousins,': 1,
#  'word,': 1,
#  'pray': 11,
#  'Two': 1,
#  'Truths': 1,
#  'told,': 1,
#  'happy': 2,
#  'Prologues': 1,
#  'swelling': 1,
#  'Act': 1,
#  'Imperiall': 2,
#  'Theame.': 1,
#  'thanke': 4,
#  'Gentlemen:': 1,
#  'supernaturall': 1,
#  'solliciting': 1,
#  'Cannot': 2,
#  'ill;': 1,
#  'good.': 2,
#  'ill?': 1,
#  'giuen': 5,
#  'successe,': 1,
#  'Commencing': 1,
#  'Truth?': 1,
#  'good?': 1,
#  'yeeld': 4,
#  'suggestion,': 1,
#  'Whose': 9,
#  'horrid': 3,
#  'Image': 1,
#  'vnfixe': 1,
#  'Heire,': 1,
#  'seated': 1,
#  'Heart': 5,
#  'knock': 1,
#  'Ribbes,': 1,
#  'Against': 5,
#  'Nature?': 1,
#  'Present': 2,
#  'Feares': 2,
#  'horrible': 2,
#  'Imaginings:': 1,
#  'Thought,': 1,
#  'whose': 5,
#  'Murther': 2,
#  'Shakes': 1,
#  'single': 3,
#  'Man,': 2,
#  'Function': 1,
#  "smother'd": 1,
#  'surmise,': 1,
#  'nothing': 8,
#  'is,': 3,
#  'how': 12,
#  "Partner's": 1,
#  'rapt': 2,
#  'Chance': 2,
#  'Crowne': 3,
#  'Without': 3,
#  'stirre': 2,
#  'New': 3,
#  'Honors': 3,
#  'Like': 6,
#  'Garments,': 1,
#  'cleaue': 2,
#  'mould,': 1,
#  'aid': 1,
#  'Come': 16,
#  'may,': 2,
#  'Houre,': 1,
#  'runs': 1,
#  'roughest': 1,
#  'Worthy': 2,
#  'wee': 3,
#  'stay': 4,
#  'leysure': 2,
#  'fauour:': 1,
#  'dull': 1,
#  'Braine': 1,
#  'wrought': 4,
#  'forgotten.': 1,
#  'Kinde': 1,
#  'Gentlemen,': 1,
#  'paines': 1,
#  'registred,': 1,
#  'turne': 2,
#  'Leafe,': 2,
#  'reade': 2,
#  'them.': 3,
#  'Let': 19,
#  'toward': 5,
#  'King:': 1,
#  'thinke': 9,
#  "chanc'd:": 1,
#  'time,': 15,
#  'Interim': 1,
#  'hauing': 2,
#  "weigh'd": 2,
#  'it,': 13,
#  'let': 16,
#  'free': 3,
#  'Hearts': 1,
#  'other': 8,
#  'Very': 1,
#  'gladly': 1,
#  'enough:': 4,
#  'friends.': 1,
#  'Quarta.': 4,
#  'Flourish.': 5,
#  'Malcolme,': 8,
#  'Attendants.': 5,
#  'Is': 19,
#  'Commission': 1,
#  "return'd?": 1,
#  'Liege,': 2,
#  'back.': 1,
#  'spoke': 3,
#  'saw': 3,
#  'die:': 1,
#  'frankly': 1,
#  "Confess'd": 1,
#  'Treasons,': 1,
#  "implor'd": 1,
#  'Highnesse': 8,
#  'Pardon,': 1,
#  'forth': 6,
#  'deepe': 3,
#  'Repentance:': 1,
#  'Life': 5,
#  'became': 2,
#  'leauing': 1,
#  'it.': 8,
#  'Hee': 1,
#  "dy'de,": 1,
#  'beene': 9,
#  'studied': 1,
#  'throw': 6,
#  'away': 4,
#  'dearest': 4,
#  'thing': 5,
#  "ow'd,": 1,
#  "'twere": 2,
#  'carelesse': 1,
#  'Trifle': 1,
#  "There's": 9,
#  'Art,': 1,
#  'finde': 11,
#  'Mindes': 1,
#  'construction': 1,
#  'Face.': 1,
#  'Gentleman,': 1,
#  'whom': 6,
#  'built': 1,
#  'An': 2,
#  'absolute': 3,
#  'Trust.': 1,
#  'Rosse,': 6,
#  'worthyest': 1,
#  'sinne': 2,
#  'Ingratitude': 1,
#  'euen': 6,
#  'Was': 13,
#  'me.': 9,
#  'art': 7,
#  'before,': 4,
#  'swiftest': 1,
#  'Wing': 2,
#  'Recompence': 1,
#  'slow,': 2,
#  'ouertake': 1,
#  'thee.': 3,
#  ...}

# %% [markdown]
# ### Step 2: Testing with the Main Program

# %% [markdown]
# The main program is provided for you, to help with testing your code.  Once your function is working, you may want to explore the data a bit,
# and see what other words are frequently (or infrequently) found!
#
# Notice that this approach treats “The” and “the” as different words, and also includes the punctuation with the word... if you want to experiment (optional!), you could try creating a separate function that would first change the words to lowercase, and remove the punctuation.  However, if you do this, be sure to leave the original function, as that is what the autograder is looking at!

# %%
def process_file(filename):
    my_dict = {}
    my_list = []
    try: 
       with open(filename, 'r') as file:
        for each_line in file:
            my_list += each_line.split()
        for each in my_list:
            if each in my_dict:
                my_dict[each] += 1
            else:
                my_dict[each] = 1
        return my_dict
    except FileNotFoundError:
        return "Not quite. Verify that your filename is accurate"
def main(): 
    # Source: https://www.gutenberg.org/cache/epub/2264/pg2264.txt
    macbeth_filename = 'Macbeth.txt'

    # open and process file
    macbeth_dict = process_file(macbeth_filename)
    
    # find a few things
    print(f'Enter filename: {macbeth_filename}')
    print(f'The word "The" appears {macbeth_dict["The"]}  times.')
    print(f'The word "the" appears {macbeth_dict["the"]} times.')
    print(f'The word "thee" appears {macbeth_dict["thee"]} times.')

    # print the matbeth dictionary
    print('The entire dictionary is here:')
    print(macbeth_dict)

main()
# Out:
# Enter filename: Macbeth.txt
# The word "The" appears 117  times.
# The word "the" appears 528 times.
# The word "thee" appears 43 times.
# The entire dictionary is here:
# {'The': 117, 'Tragedie': 1, 'of': 314, 'Macbeth': 26, 'Actus': 5, 'Primus.': 1, 'Scoena': 1, 'Prima.': 5, 'Thunder': 2, 'and': 375, 'Lightning.': 1, 'Enter': 73, 'three': 13, 'Witches.': 4, '1.': 21, 'When': 21, 'shall': 47, 'we': 56, 'meet': 5, 'againe?': 2, 'In': 28, 'Thunder,': 1, 'Lightning,': 1, 'or': 25, 'in': 167, 'Raine?': 1, '2.': 12, 'the': 528, "Hurley-burley's": 1, 'done,': 7, "Battaile's": 1, 'lost,': 3, 'wonne': 1, '3.': 14, 'That': 80, 'will': 59, 'be': 119, 'ere': 13, 'set': 7, 'Sunne': 3, 'Where': 20, 'place?': 2, 'Vpon': 11, 'Heath': 2, 'There': 12, 'to': 310, 'with': 133, 'I': 314, 'come,': 8, 'Gray-Malkin': 1, 'All.': 13, 'Padock': 1, 'calls': 2, 'anon:': 1, 'faire': 3, 'is': 156, 'foule,': 2, 'foule': 2, 'faire,': 1, 'Houer': 1, 'through': 6, 'fogge': 1, 'filthie': 2, 'ayre.': 1, 'Exeunt.': 29, 'Scena': 22, 'Secunda.': 5, 'Alarum': 5, 'within.': 7, 'King,': 19, 'Malcome,': 1, 'Donalbaine,': 3, 'Lenox,': 8, 'attendants,': 1, 'meeting': 2, 'a': 212, 'bleeding': 1, 'Captaine.': 1, 'King.': 18, 'What': 57, 'bloody': 11, 'man': 16, 'that?': 2, 'he': 73, 'can': 20, 'report,': 3, 'As': 33, 'seemeth': 1, 'by': 33, 'his': 126, 'plight,': 1, 'Reuolt': 1, 'newest': 3, 'state': 3, 'Mal.': 25, 'This': 24, 'Serieant,': 1, 'Who': 21, 'like': 31, 'good': 33, 'hardie': 1, 'Souldier': 2, 'fought': 1, "'Gainst": 2, 'my': 168, 'Captiuitie:': 1, 'Haile': 4, 'braue': 2, 'friend;': 1, 'Say': 3, 'knowledge': 1, 'Broyle,': 1, 'thou': 61, 'didst': 2, 'leaue': 10, 'it': 111, 'Cap.': 3, 'Doubtfull': 1, 'stood,': 2, 'two': 8, 'spent': 1, 'Swimmers,': 1, 'that': 140, 'doe': 26, 'cling': 2, 'together,': 2, 'And': 169, 'choake': 1, 'their': 57, 'Art:': 1, 'mercilesse': 1, 'Macdonwald': 1, '(Worthie': 1, 'Rebell,': 1, 'for': 77, 'multiplying': 1, 'Villanies': 1, 'Nature': 12, 'Doe': 4, 'swarme': 1, 'vpon': 47, 'him)': 2, 'from': 47, 'Westerne': 1, 'Isles': 1, 'Of': 22, 'Kernes': 2, 'Gallowgrosses': 1, "supply'd,": 1, 'Fortune': 1, 'on': 47, 'damned': 2, 'Quarry': 2, 'smiling,': 1, "Shew'd": 1, 'Rebells': 1, 'Whore:': 1, 'but': 60, "all's": 3, 'too': 17, 'weake:': 1, 'For': 30, '(well': 1, 'hee': 6, 'deserues': 2, 'Name)': 1, 'Disdayning': 1, 'Fortune,': 4, 'brandisht': 1, 'Steele,': 2, 'Which': 35, "smoak'd": 1, 'execution': 3, '(Like': 1, 'Valours': 1, 'Minion)': 1, "caru'd": 1, 'out': 15, 'passage,': 1, 'Till': 11, "fac'd": 1, 'Slaue:': 1, "neu'r": 1, 'shooke': 1, 'hands,': 4, 'nor': 20, 'bad': 4, 'farwell': 1, 'him,': 18, "vnseam'd": 1, 'him': 56, 'Naue': 1, "toth'": 4, 'Chops,': 1, "fix'd": 1, 'Head': 2, 'our': 103, 'Battlements': 1, 'O': 13, 'valiant': 3, 'Cousin,': 2, 'worthy': 13, 'Gentleman': 1, 'whence': 4, "'gins": 1, 'reflection,': 1, 'Shipwracking': 1, 'Stormes,': 1, 'direfull': 1, 'Thunders:': 1, 'So': 26, 'Spring,': 2, 'comfort': 4, "seem'd": 2, 'Discomfort': 1, 'swells:': 1, 'Marke': 1, 'King': 14, 'Scotland,': 4, 'marke,': 1, 'No': 16, 'sooner': 2, 'Iustice': 2, 'had,': 2, 'Valour': 1, "arm'd,": 1, "Compell'd": 1, 'these': 20, 'skipping': 1, 'trust': 2, 'heeles,': 2, 'But': 60, 'Norweyan': 3, 'Lord,': 17, 'surueying': 1, 'vantage,': 1, 'With': 19, 'furbusht': 1, 'Armes,': 1, 'new': 9, 'supplyes': 1, 'men,': 7, 'Began': 1, 'fresh': 1, 'assault': 1, "Dismay'd": 1, 'not': 135, 'this': 71, 'Captaines,': 1, 'Banquoh?': 1, 'Yes,': 2, 'as': 52, 'Sparrowes,': 1, 'Eagles;': 1, 'Or': 12, 'Hare,': 1, 'Lyon:': 1, 'If': 28, 'say': 19, 'sooth,': 2, 'must': 33, 'report': 5, 'they': 56, 'were': 32, 'Cannons': 1, "ouer-charg'd": 1, 'double': 4, 'Cracks,': 1, 'doubly': 1, 'redoubled': 1, 'stroakes': 2, 'Foe:': 1, 'Except': 1, 'meant': 1, 'bathe': 1, 'reeking': 1, 'Wounds,': 1, 'memorize': 1, 'another': 4, 'Golgotha,': 1, 'cannot': 18, 'tell:': 1, 'am': 28, 'faint,': 1, 'My': 33, 'Gashes': 1, 'cry': 2, 'helpe': 3, 'well': 9, 'thy': 46, 'words': 4, 'become': 4, 'thee,': 8, 'wounds,': 1, 'They': 12, 'smack': 1, 'Honor': 6, 'both:': 2, 'Goe': 5, 'get': 5, 'Surgeons.': 1, 'Rosse': 3, 'Angus.': 3, 'comes': 9, 'here?': 3, 'Thane': 19, 'Lenox.': 20 ...

# %% [markdown]
# #### Sample Output 1
# (filename was “doesnotexist.txt”)
#
# There is no file named `doesnotexist.txt` in this directory.
#
# #### Sample output 2
# (filename was “Macbeth.txt”)
#
#     Enter filename:  Macbeth.txt
#     The word "The" appears 117 times.
#     The word "the" appears 528 times.
#     The word "thee" appears 43 times.
#     The entire dictionary is here:
#     {'The': 117, 'Tragedie': 1, 'of': 314, 'Macbeth': 26, 'Actus': 5, 'Primus.': 1,
#     'Scoena': 1, 'Prima.': 5, 'Thunder': 2, 'and': 375, 'Lightning.': 1, 'Enter': 73,
#     'three': 13, 'Witches.': 4, '1.': 21, 'When': 21, 'shall': 47, 'we': 56,
#     'meet': 5, 'againe?': 2, 'In': 28, 'Thunder,': 1, 'Lightning,': 1, 'or': 25,
#     'in': 167, 'Raine?': 1, '2.': 12, 'the': 528, "Hurley-burley's": 1, 'done,': 7,
#     "Battaile's": 1, 'lost,': 3, 'wonne': 1, '3.': 14, 'That': 80, 'will': 59,
#     'be': 119, 'ere': 13, 'set': 7, 'Sunne': 3, 'Where': 20, 'place?': 2,
#     'Vpon': 11, 'Heath': 2,
#
#     .... <snip> for brevity -- the dictionary is many pages long!

# %% [markdown]
# ### Step 3: Graded Test Cases

# %%
### GRADED TEST CASE 1: Correct file is opened & dictionary is returned
filename = 'Macbeth.txt'
result = type(process_file(filename))

assert str(result) == "<class 'dict'>", "Not quite. Verify that you are returning a dictionary and have accessed a real file. "

# %%
### GRADED TEST CASE 2: Incorrect file is opened
errorCheck = bool

filename = 'Macbeth2.txt'
result = process_file(filename)

if "{'File not found', 'Error'}" in result:
    errorCheck = True
    
assert errorCheck, "Not quite. Verify that your filename is accurate"

# %%
### GRADED TEST CASE 3: Word grouping test
word_group = bool

filename = 'Macbeth.txt'
result = process_file(filename)

try:
    if result["The"] == 117:
        word_group = True
except:
    word_group = False

assert word_group == True, "Not quite, verify you've grouped words correctly in your dictionary."

# %% [markdown]
# ### Step 4: Submit your Work for Grading

# %% [markdown]
# Congratulations on completing this assignment.
#
# To receive a final score for your work, please select the "Submit Assignment" button at the top of your lab.
